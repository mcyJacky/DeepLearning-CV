# %%
from keras.models import Sequential
from keras.layers import Conv2D,MaxPool2D,Activation,Dropout,Flatten,Dense
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator,img_to_array,load_img
# Out:
# Using TensorFlow backend.

# %%
# 定义模型
model = Sequential()
model.add(Conv2D(input_shape=(150,150,3),filters=32,kernel_size=3,padding='same',activation='relu'))
model.add(Conv2D(filters=32,kernel_size=3,padding='same',activation='relu'))
model.add(MaxPool2D(pool_size=2, strides=2))

model.add(Conv2D(filters=64,kernel_size=3,padding='same',activation='relu'))
model.add(Conv2D(filters=64,kernel_size=3,padding='same',activation='relu'))
model.add(MaxPool2D(pool_size=2, strides=2))

model.add(Conv2D(filters=128,kernel_size=3,padding='same',activation='relu'))
model.add(Conv2D(filters=128,kernel_size=3,padding='same',activation='relu'))
model.add(MaxPool2D(pool_size=2, strides=2))

model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2,activation='softmax'))

# 定义优化器
adam = Adam(lr=1e-4)

# 定义优化器，代价函数，训练过程中计算准确率
model.compile(optimizer=adam,loss='categorical_crossentropy',metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(
    rotation_range = 40,     # 随机旋转度数
    width_shift_range = 0.2, # 随机水平平移
    height_shift_range = 0.2,# 随机竖直平移
    rescale = 1/255,         # 数据归一化
    shear_range = 20,       # 随机错切变换
    zoom_range = 0.2,        # 随机放大
    horizontal_flip = True,  # 水平翻转
    fill_mode = 'nearest',   # 填充方式
) 
test_datagen = ImageDataGenerator(
    rescale = 1/255,         # 数据归一化
)

# %%
batch_size = 32

# 生成训练数据
train_generator = train_datagen.flow_from_directory(
    'image/train',
    target_size=(150,150),
    batch_size=batch_size,
    )

# 测试数据
test_generator = test_datagen.flow_from_directory(
    'image/test',
    target_size=(150,150),
    batch_size=batch_size,
    )
# Out:
# Found 400 images belonging to 2 classes.
# Found 200 images belonging to 2 classes.

# %%
train_generator.class_indices
# Out:
# {'cat': 0, 'dog': 1}

# %%
model.fit_generator(train_generator,steps_per_epoch=len(train_generator),epochs=30,validation_data=test_generator,validation_steps=len(test_generator))
# Out:
# Epoch 1/30
# 13/13 [==============================] - 13s 962ms/step - loss: 0.6986 - acc: 0.5171 - val_loss: 0.6936 - val_acc: 0.5000
# Epoch 2/30
# 13/13 [==============================] - 3s 254ms/step - loss: 0.6940 - acc: 0.4957 - val_loss: 0.6897 - val_acc: 0.5000
# Epoch 3/30
# 13/13 [==============================] - 3s 256ms/step - loss: 0.6912 - acc: 0.5002 - val_loss: 0.6881 - val_acc: 0.5000
# Epoch 4/30
# 13/13 [==============================] - 3s 257ms/step - loss: 0.6889 - acc: 0.5046 - val_loss: 0.6857 - val_acc: 0.5000
# Epoch 5/30
# 13/13 [==============================] - 4s 287ms/step - loss: 0.6817 - acc: 0.5165 - val_loss: 0.6770 - val_acc: 0.5000
# Epoch 6/30
# 13/13 [==============================] - 4s 293ms/step - loss: 0.6683 - acc: 0.5714 - val_loss: 0.6725 - val_acc: 0.5100
# Epoch 7/30
# 13/13 [==============================] - 4s 332ms/step - loss: 0.6681 - acc: 0.5747 - val_loss: 0.6600 - val_acc: 0.5350
# Epoch 8/30
# 13/13 [==============================] - 4s 325ms/step - loss: 0.6587 - acc: 0.6107 - val_loss: 0.6551 - val_acc: 0.5850
# Epoch 9/30
# 13/13 [==============================] - 4s 313ms/step - loss: 0.6623 - acc: 0.6104 - val_loss: 0.6577 - val_acc: 0.5450
# Epoch 10/30
# 13/13 [==============================] - 4s 334ms/step - loss: 0.6460 - acc: 0.6222 - val_loss: 0.7896 - val_acc: 0.5050
# Epoch 11/30
# 13/13 [==============================] - 4s 344ms/step - loss: 0.6574 - acc: 0.5794 - val_loss: 0.6564 - val_acc: 0.6050
# Epoch 12/30
# 13/13 [==============================] - 4s 324ms/step - loss: 0.6403 - acc: 0.6272 - val_loss: 0.6811 - val_acc: 0.5550
# Epoch 13/30
# 13/13 [==============================] - 4s 328ms/step - loss: 0.6533 - acc: 0.6441 - val_loss: 0.6535 - val_acc: 0.6100
# Epoch 14/30
# 13/13 [==============================] - 3s 269ms/step - loss: 0.6588 - acc: 0.6465 - val_loss: 0.6625 - val_acc: 0.5850
# Epoch 15/30
# 13/13 [==============================] - 3s 264ms/step - loss: 0.6440 - acc: 0.6508 - val_loss: 0.6504 - val_acc: 0.5900
# Epoch 16/30
# 13/13 [==============================] - 4s 294ms/step - loss: 0.6332 - acc: 0.6321 - val_loss: 0.6683 - val_acc: 0.5450
# Epoch 17/30
# 13/13 [==============================] - 4s 298ms/step - loss: 0.6290 - acc: 0.6682 - val_loss: 0.6587 - val_acc: 0.5950
# Epoch 18/30
# 13/13 [==============================] - 4s 303ms/step - loss: 0.6067 - acc: 0.6701 - val_loss: 0.6453 - val_acc: 0.6600
# Epoch 19/30
# 13/13 [==============================] - 4s 298ms/step - loss: 0.6268 - acc: 0.6486 - val_loss: 0.7539 - val_acc: 0.5400
# Epoch 20/30
# 13/13 [==============================] - 4s 305ms/step - loss: 0.6101 - acc: 0.6706 - val_loss: 0.6780 - val_acc: 0.5700
# Epoch 21/30
# 13/13 [==============================] - 4s 317ms/step - loss: 0.5900 - acc: 0.6875 - val_loss: 0.6731 - val_acc: 0.5750
# Epoch 22/30
# 13/13 [==============================] - 4s 305ms/step - loss: 0.6153 - acc: 0.6660 - val_loss: 0.6594 - val_acc: 0.6250
# Epoch 23/30
# 13/13 [==============================] - 4s 299ms/step - loss: 0.6087 - acc: 0.6565 - val_loss: 0.6764 - val_acc: 0.5650
# Epoch 24/30
# 13/13 [==============================] - 4s 309ms/step - loss: 0.5863 - acc: 0.6975 - val_loss: 0.6619 - val_acc: 0.6250
# Epoch 25/30
# 13/13 [==============================] - 4s 301ms/step - loss: 0.5698 - acc: 0.6996 - val_loss: 0.6859 - val_acc: 0.6000
# Epoch 26/30
# 13/13 [==============================] - 4s 319ms/step - loss: 0.5803 - acc: 0.7044 - val_loss: 0.6458 - val_acc: 0.6550
# Epoch 27/30
# 13/13 [==============================] - 4s 323ms/step - loss: 0.5871 - acc: 0.7018 - val_loss: 0.6845 - val_acc: 0.5750
# Epoch 28/30
# 13/13 [==============================] - 4s 325ms/step - loss: 0.5648 - acc: 0.7138 - val_loss: 0.6358 - val_acc: 0.6200
# Epoch 29/30
# 13/13 [==============================] - 4s 330ms/step - loss: 0.5716 - acc: 0.6758 - val_loss: 0.6723 - val_acc: 0.6050
# Epoch 30/30
# 13/13 [==============================] - 4s 312ms/step - loss: 0.5502 - acc: 0.7288 - val_loss: 0.6591 - val_acc: 0.6350

# %%
# pip install h5py
model.save('model_cnn.h5')

# %% [markdown]
# # 测试

# %%
from keras.models import load_model
import numpy as np

label = np.array(['cat','dog'])
# 载入模型
model = load_model('model_cnn.h5')

# 导入图片
image = load_img('image/test/cat/cat.1002.jpg')
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=379x407 at 0x1C0E5628240>

# %%
image = image.resize((150,150))
image = img_to_array(image)
image = image/255
image = np.expand_dims(image,0)
image.shape
# Out:
# (1, 150, 150, 3)

# %%
print(label[model.predict_classes(image)])
# Out:
# ['cat']
