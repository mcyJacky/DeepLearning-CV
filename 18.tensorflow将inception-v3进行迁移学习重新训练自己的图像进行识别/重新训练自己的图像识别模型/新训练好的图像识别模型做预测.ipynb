# %%
import tensorflow as tf
import os
import numpy as np
import re
from PIL import Image
import matplotlib.pyplot as plt

# %%
lines = tf.gfile.GFile('output_labels.txt').readlines()
uid_to_human = {} #{0: 'animal', 1: 'house', 2: 'plane', 3: 'flower', 4: 'guitar'}

# 一行一行读取数据
for uid,line in enumerate(lines) :
    #去掉换行符
    line=line.strip('\n')
    uid_to_human[uid] = line

# 分类编号变成描述
def id_to_string(node_id):
    if node_id not in uid_to_human:
        return ''
    return uid_to_human[node_id]


# 创建一个图来存放训练好的模型
with tf.gfile.GFile('output_graph.pb', 'rb') as f:
    graph_def = tf.GraphDef()
    graph_def.ParseFromString(f.read())
    tf.import_graph_def(graph_def, name='')


with tf.Session() as sess:
    # final_result为输出tensor的名字
    softmax_tensor = sess.graph.get_tensor_by_name('final_result:0')
    # 遍历目录
    for root,dirs,files in os.walk('images/'):
        for file in files:
            # 载入图片
            image_data = tf.gfile.GFile(os.path.join(root,file), 'rb').read()
            # 把图像数据传入模型获得模型输出结果
            predictions = sess.run(softmax_tensor,{'DecodeJpeg/contents:0': image_data})
            # 把结果转为1维数据
            predictions = np.squeeze(predictions)
            # 打印图片路径及名称
            image_path = os.path.join(root,file)
            print(image_path)
            # 显示图片
            img=Image.open(image_path)
            plt.imshow(img)
            plt.axis('off')
            plt.show()

            # 排序
            top_k = predictions.argsort()[::-1]
            for node_id in top_k:     
                # 获取分类名称
                human_string = id_to_string(node_id)
                # 获取该分类的置信度
                score = predictions[node_id]
                print('%s (score = %.5f)' % (human_string, score))
            print()
# Out:
# images/animal1.jpg
# animal (score = 0.43110)
# plane (score = 0.21084)
# flower (score = 0.13817)
# house (score = 0.11133)
# guitar (score = 0.10856)
#
# images/animal2.jpg
# animal (score = 0.52746)
# plane (score = 0.17728)
# flower (score = 0.14794)
# guitar (score = 0.07415)
# house (score = 0.07317)
#
# images/animal3.jpg
# animal (score = 0.89350)
# plane (score = 0.03415)
# flower (score = 0.03276)
# guitar (score = 0.02054)
# house (score = 0.01905)
#
# images/flower1.jpg
# flower (score = 0.98908)
# animal (score = 0.00347)
# plane (score = 0.00320)
# house (score = 0.00255)
# guitar (score = 0.00170)
#
# images/flower2.jpg
# flower (score = 0.98485)
# house (score = 0.00511)
# animal (score = 0.00377)
# plane (score = 0.00348)
# guitar (score = 0.00279)
#
# images/flower3.jpg
# flower (score = 0.98670)
# animal (score = 0.00359)
# house (score = 0.00327)
# plane (score = 0.00323)
# guitar (score = 0.00322)
#
# images/guitar1.jpg
# guitar (score = 0.97203)
# animal (score = 0.00846)
# flower (score = 0.00736)
# plane (score = 0.00623)
# house (score = 0.00592)
#
# images/guitar2.jpg
# guitar (score = 0.97357)
# flower (score = 0.00750)
# animal (score = 0.00740)
# plane (score = 0.00614)
# house (score = 0.00539)
#
# images/guitar3.jpg
# guitar (score = 0.98561)
# house (score = 0.00411)
# flower (score = 0.00369)
# animal (score = 0.00349)
# plane (score = 0.00311)
#
# images/house1.jpg
# house (score = 0.93558)
# flower (score = 0.02400)
# animal (score = 0.01869)
# plane (score = 0.01355)
# guitar (score = 0.00819)
#
# images/house2.jpg
# house (score = 0.98765)
# animal (score = 0.00449)
# plane (score = 0.00321)
# flower (score = 0.00309)
# guitar (score = 0.00156)
#
# images/house3.jpg
# house (score = 0.93720)
# plane (score = 0.01913)
# flower (score = 0.01707)
# animal (score = 0.01479)
# guitar (score = 0.01180)
#
# images/plane1.jpg
# plane (score = 0.96315)
# animal (score = 0.01502)
# guitar (score = 0.00814)
# flower (score = 0.00691)
# house (score = 0.00678)
#
# images/plane2.jpg
# plane (score = 0.89427)
# animal (score = 0.04046)
# flower (score = 0.02703)
# guitar (score = 0.01948)
# house (score = 0.01876)
#
# images/plane3.jpg
# plane (score = 0.98077)
# animal (score = 0.00757)
# house (score = 0.00402)
# flower (score = 0.00399)
# guitar (score = 0.00364)
